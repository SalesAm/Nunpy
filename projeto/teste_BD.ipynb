# %% [markdown]
# # Análise de banco de dados
#
# **Disciplina**: Programação para Ciência dos Dados
# **Dicentes**: Emily Sales Emiliandro
#
#
# ## Apresentação
#
# No cenário atual com o novo corona vírus e a grande preocupação da população mundial a respeito deste assunto, achou-se necessário fazer uma análise simples para por em prátia o conteúdo compartilhado em sala de aula.
#
# **Objetivo:**
# Separar as dúvidas/perguntas sobre o COVID-19 e observar quais tipos de questionamentos mais feito na rede social relacionado ao vírus.
# Qual personalidade mais comentada na rede quando o assunto é COVID-19.
# Se possível qual a região que mais questiona sobre o vírus.y.

# %%
import pandas as pd
import datetime
import numpy as np
import matplotlib.pyplot as plt
import re
import nltk
from nltk.stem import PorterStemmer 
from nltk.tokenize import word_tokenize 
from nltk.corpus import stopwords
import folium 
import pandas as pd
import folium.plugins as plugins

# %%
BD = pd.read_csv('dados-curso-completo.csv')

# %%
BD.head()
# Out:
#                   data              usuario          apelido  \
# 0  2020-03-23 18:51:14             Gaboardi          fraslee
# 1  2020-03-18 03:18:14   Seu Zé da Farmácia  seuzedafarmacia
# 2  2020-03-29 12:09:27  Marília Oliveira 🇧🇷  Marioliveira_gb
# 3  2020-04-01 21:11:07                    🚩      santosodeto
# 4  2020-03-19 17:49:40       Nova Impressão   novaimpressao_
#
#                                                texto  retweet  seguidores  \
# 0  @BolsonaroSP Cade o fundão deputado??? Congres...        0         138
# 1  Em ação preventiva, o Governo do Estado suspen...        0          56
# 2  Incrível como os defensores do fim do distanci...        0           5
# 3  Fumaça de cigarro pode propagar coronavírus? h...        0        1885
# 4  🚨Todos juntos contra COVID-19💪\n\nSolicite seu...        0         124
#
#   idioma     lugar    pais sigla  latitude  longitude hashtags
# 0     pt       NaN     NaN   NaN       NaN        NaN       []
# 1     pt       NaN     NaN   NaN       NaN        NaN       []
# 2     pt       NaN     NaN   NaN       NaN        NaN       []
# 3     pt       NaN     NaN   NaN       NaN        NaN       []
# 4     pt  Brasília  Brazil    BR  -47.8778  -15.77691       []

# %%
BD
# Out:
#                         data                         usuario          apelido  \
# 0        2020-03-23 18:51:14                        Gaboardi          fraslee
# 1        2020-03-18 03:18:14              Seu Zé da Farmácia  seuzedafarmacia
# 2        2020-03-29 12:09:27             Marília Oliveira 🇧🇷  Marioliveira_gb
# 3        2020-04-01 21:11:07                               🚩      santosodeto
# 4        2020-03-19 17:49:40                  Nova Impressão   novaimpressao_
# ...                      ...                             ...              ...
# 1658820  2020-03-13 17:26:18                           broca       whoisdrill
# 1658821  2020-05-12 13:02:34                       Renato 🇧🇷   VerdadeExpress
# 1658822  2020-03-19 18:16:30                   eugeniocosta8    EugenioCosta8
# 1658823  2020-04-07 18:14:45  Wagner Mota - Seriedade + Geek     wagnermota75
# 1658824  2020-06-02 16:04:51                       Fotógrafo  omarcelogoulart
#
#                                                      texto  retweet  \
# 0        @BolsonaroSP Cade o fundão deputado??? Congres...        0
# 1        Em ação preventiva, o Governo do Estado suspen...        0
# 2        Incrível como os defensores do fim do distanci...        0
# 3        Fumaça de cigarro pode propagar coronavírus? h...        0
# 4        🚨Todos juntos contra COVID-19💪\n\nSolicite seu...        0
# ...                                                    ...      ...
# 1658820  oms: tamo tendo pandemia evitar\n conglomerado...        0
# 1658821  @OsmarTerra Sr. Osmar Terra, gostaria de ouvir...        0
# 1658822  CIENTISTA DE HARVARD PREVÊ QUE ATÉ 70% DO MUND...        3
# 1658823  #BolsonaroTemRazaoSim porque, quando a prefeit...        0
# 1658824  Em meio a uma pandemia, estamos na luta também...        0
#
#          seguidores idioma                  lugar    pais sigla  latitude  \
# 0               138     pt                    NaN     NaN   NaN       NaN
# 1                56     pt                    NaN     NaN   NaN       NaN
# 2                 5     pt                    NaN     NaN   NaN       NaN
# 3              1885     pt                    NaN     NaN   NaN       NaN
# 4               124     pt               Brasília  Brazil    BR  -47.8778
# ...             ...    ...                    ...     ...   ...       ...
# 1658820         361     pt                    NaN     NaN   NaN       NaN
# 1658821        4066     pt                    NaN     NaN   NaN       NaN
# 1658822        5307     pt                    NaN     NaN   NaN       NaN
# 1658823        1000     pt                    NaN     NaN   NaN       NaN
# 1658824         726     pt  São Félix do Araguaia  Brazil    BR  -53.0000
#
#          longitude                  hashtags
# 0              NaN                        []
# 1              NaN                        []
# 2              NaN                        []
# 3              NaN                        []
# 4        -15.77691                        []
# ...            ...                       ...
# 1658820        NaN                        []
# 1658821        NaN                        []
# 1658822        NaN           ['CORONAVIRUS']
# 1658823        NaN  ['BolsonaroTemRazaoSim']
# 1658824  -11.00000                        []
#
# [1658825 rows x 13 columns]

# %%
BD.duplicated().sum() #verificando linhas iguais
# Out:
# 2

# %%
BD.isnull().sum() #contando (identificando) dados faltantes
# Out:
# data                0
# usuario            57
# apelido             0
# texto               0
# retweet             0
# seguidores          0
# idioma              0
# lugar         1584220
# pais          1584225
# sigla         1584230
# latitude      1650105
# longitude     1650105
# hashtags            0
# dtype: int64

# %%
BD.dropna (inplace=True) #limpando dados nulos de todo o banco
BD.isnull().sum()
# Out:
# data          0
# usuario       0
# apelido       0
# texto         0
# retweet       0
# seguidores    0
# idioma        0
# lugar         0
# pais          0
# sigla         0
# latitude      0
# longitude     0
# hashtags      0
# dtype: int64

# %%
banco=BD.loc[BD['idioma']=='pt'] #do banco completo, pegando só o que está em PT
banco
# Out:
#                         data                    usuario          apelido  \
# 4        2020-03-19 17:49:40             Nova Impressão   novaimpressao_
# 261      2020-04-16 00:34:54               Felipe Silva    felipesilvasr
# 265      2020-05-03 13:48:52               Bruno Fortes         Brunaogf
# 289      2020-03-31 17:52:37         jairo santos souza        soi_jairo
# 477      2020-03-24 17:27:29             Carolina Porne    carolinaporne
# ...                      ...                        ...              ...
# 1658284  2020-04-16 19:45:29  Bruno Agrofoglio Ferreira       agrofoglio
# 1658503  2020-05-31 12:38:32       BARÃO DE CEARA MIRIM  baraocearamirim
# 1658514  2020-03-23 23:48:19             Diego Pelizari    diegopelizari
# 1658760  2020-05-12 09:30:34           Hamilton Valerio         hvalerio
# 1658824  2020-06-02 16:04:51                  Fotógrafo  omarcelogoulart
#
#                                                      texto  retweet  \
# 4        🚨Todos juntos contra COVID-19💪\n\nSolicite seu...        0
# 261      A secretaria de Saúde da Paraíba confirmou nes...        0
# 265      Domingão taí! ☀️\nEm casa! 😐😬\nVai passar! 🙏🏼\...        0
# 289      Seguindo orientação do Presidente Bolsonaro, o...        0
# 477      #5 - Isolamento social não é desculpa para fic...        0
# ...                                                    ...      ...
# 1658284  Criei um bot para o Telegram raspando os dados...        0
# 1658503  Serra da Formiga em Riachuelo RN\nDestino marc...        0
# 1658514  #Repost de respeito da parceira agroschoolbras...        0
# 1658760  Mais um amanhecer em isolamento social. em Pra...        0
# 1658824  Em meio a uma pandemia, estamos na luta também...        0
#
#          seguidores idioma                    lugar    pais sigla   latitude  \
# 4               124     pt                 Brasília  Brazil    BR -47.877800
# 261             150     pt                  Taperoá  Brazil    BR -36.825000
# 265             120     pt                Fortaleza  Brazil    BR -38.526600
# 289              22     pt        Euclides da Cunha  Brazil    BR -39.014620
# 477             373     pt                Guarulhos  Brazil    BR -46.495600
# ...             ...    ...                      ...     ...   ...        ...
# 1658284          49     pt                 Paulínia  Brazil    BR -47.203010
# 1658503         808     pt                Riachuelo  Brazil    BR -35.823770
# 1658514         174     pt    São Félix do Araguaia  Brazil    BR -53.000000
# 1658760         176     pt  Jaboatão dos Guararapes  Brazil    BR -34.919555
# 1658824         726     pt    São Félix do Araguaia  Brazil    BR -53.000000
#
#          longitude                                           hashtags
# 4       -15.776910                                                 []
# 261      -7.162778                                                 []
# 265      -3.729300  ['emcasa', 'isolamentosocial', 'saude', 'quero...
# 289     -10.505250                                                 []
# 477     -23.445600                                                 []
# ...            ...                                                ...
# 1658284 -22.757163                                                 []
# 1658503  -5.815792                                                 []
# 1658514 -11.000000                                         ['Repost']
# 1658760  -8.198139                                                 []
# 1658824 -11.000000                                                 []
#
# [8573 rows x 13 columns]

# %%
banco.filter(items=['apelido','pais']).groupby('pais').count().sort_values(by='apelido',ascending=False) #tentando filtrar e ordenar por quantidade
# Out:
#                               apelido
# pais
# Brazil                           7660
# Portugal                          553
# United States                      94
# Spain                              31
# India                              30
# Italy                              25
# Canada                             20
# People's Republic of China         16
# United Kingdom                     12
# Angola                             12
# France                             11
# Ecuador                            10
# Argentina                           8
# Republic of Mozambique              8
# Mexico                              7
# Chile                               6
# Japan                               6
# Ireland                             6
# Germany                             5
# Indonesia                           4
# Vietnam                             3
# New Zealand                         3
# Australia                           3
# Vatican City                        3
# South Africa                        3
# Republic of the Philippines         2
# Belgium                             2
# Switzerland                         2
# Thailand                            2
# Peru                                2
# Colombia                            2
# Curaçao                             1
# Paraguay                            1
# Venezuela                           1
# Cyprus                              1
# Uruguay                             1
# Czech Republic                      1
# Austria                             1
# Turkey                              1
# The Netherlands                     1
# Democratic Republic of Congo        1
# Denmark                             1
# Dominican Republic                  1
# Guadeloupe                          1
# Senegal                             1
# Romania                             1
# Hellas                              1
# Israel                              1
# Qatar                               1
# Cape Verde                          1
# Malaysia                            1
# Chad                                1
# Panama                              1

# %%
banco[banco['texto'].str.contains('covid')]
# Out:
#                         data                 usuario          apelido  \
# 2469     2020-06-26 18:02:23  Augusto Delfim Moreira  Augustodelfimmo
# 3420     2020-04-09 22:32:22      Alexandre Cezar Fh  AlexandreCezarf
# 8310     2020-03-13 21:02:00             STEⓋE BOZIC      STEVE_BOZIC
# 12194    2020-03-29 18:52:50      x Fabim x ︻┳ テ = 一          xfabimx
# 14110    2020-05-14 14:55:00         BLACK BEAUTIFUL  Reinald43867320
# ...                      ...                     ...              ...
# 1648773  2020-02-29 14:03:33     Mark Hillary (em 🏠)      markhillary
# 1653097  2020-03-23 14:23:04               Vamu Ver!         Vamu_Ver
# 1654902  2020-05-24 12:07:02       Cristiano Ricelli  cristianoriceli
# 1654971  2020-04-17 01:57:31           Zap Bolsonaro     BolsonaroZap
# 1656662  2020-03-31 17:05:13                Dj Hadad   djrobertohadad
#
#                                                      texto  retweet  \
# 2469     Continuamos na Fase Laranja #sjcampos #sjc #co...        0
# 3420     Mais que #irmaos ...\nSomos #siblings !!!\n\na...        0
# 8310     #CANADA #covid_19 #covıd19 #coronavirus #truth...        0
# 12194    Né Alice uma piscina e um sorvete nem cai bem ...        0
# 14110    Hoje a nossa história matutino em combatê ao c...        0
# ...                                                    ...      ...
# 1648773  São Paulo coronavírus #máscara 😷 #saopaulo #co...        0
# 1653097  Enquanto isso, após duas semanas em isolamento...        0
# 1654902  O ex-prefeito de Patos e ex-deputado, Dinaldo ...        1
# 1654971  Chegaram as máscaras para os petistas. #covid1...        0
# 1656662  Todos Contra corona vkrus Covid-19 #covid19 #c...        0
#
#          seguidores idioma                lugar           pais sigla  \
# 2469             20     pt  São José dos Campos         Brazil    BR
# 3420             15     pt             Curitiba         Brazil    BR
# 8310            466     pt              Toronto         Canada    CA
# 12194           590     pt            Sao Paulo         Brazil    BR
# 14110            15     pt               Ilhéus         Brazil    BR
# ...             ...    ...                  ...            ...   ...
# 1648773       17645     pt            Sao Paulo         Brazil    BR
# 1653097         639     pt               Lisbon       Portugal    PT
# 1654902         276     pt          João Pessoa         Brazil    BR
# 1654971         131     pt               Boston  United States    US
# 1656662        1100     pt                 Magé         Brazil    BR
#
#           latitude  longitude  \
# 2469    -45.886944 -23.178889
# 3420    -49.276342 -25.428955
# 8310    -79.387200  43.648000
# 12194   -46.649423 -23.594328
# 14110   -39.062848 -14.752700
# ...            ...        ...
# 1648773 -46.665490 -23.564160
# 1653097  -9.183333  38.700000
# 1654902 -34.862700  -7.120700
# 1654971 -71.056500  42.357700
# 1656662 -43.193706 -22.617960
#
#                                                   hashtags
# 2469                        ['sjcampos', 'sjc', 'covid19']
# 3420     ['irmaos', 'siblings', 'quarentinewithme', 'qu...
# 8310     ['CANADA', 'covid_19', 'covıd19', 'coronavirus...
# 12194                                          ['covid19']
# 14110                                                   []
# ...                                                    ...
# 1648773  ['máscara', 'saopaulo', 'covid19', 'coronavirus']
# 1653097  ['vamuver', 'isolamentosocial', 'covid19portug...
# 1654902                                                 []
# 1654971                                        ['covid19']
# 1656662  ['covid19', 'covid', 'coronavirus', 'mendigo',...
#
# [959 rows x 13 columns]

# %%
pergunta1=banco[banco['texto'].str.contains('governo')].count() #contando quantas vezes a palavra 'presidente' é cidada.
pergunta2=banco[banco['texto'].str.contains('Governo')].count()
p=pergunta1+pergunta2
p
# Out:
# data          145
# usuario       145
# apelido       145
# texto         145
# retweet       145
# seguidores    145
# idioma        145
# lugar         145
# pais          145
# sigla         145
# latitude      145
# longitude     145
# hashtags      145
# dtype: int64

# %%
prop1=(p/len(banco))*100 #proporção da palavra no conjunto
prop1
# Out:
# data          1.691357
# usuario       1.691357
# apelido       1.691357
# texto         1.691357
# retweet       1.691357
# seguidores    1.691357
# idioma        1.691357
# lugar         1.691357
# pais          1.691357
# sigla         1.691357
# latitude      1.691357
# longitude     1.691357
# hashtags      1.691357
# dtype: float64

# %%
ministro1=banco[banco['texto'].str.contains('ministro')].count() #contando quantas vezes a palavra 'presidente' é cidada.
ministro2=banco[banco['texto'].str.contains('Ministro')].count()
M=ministro1+ministro2
M #valor total de quantidade de vezes que a palavra ministro é falada no banco com o idioma PT
# Out:
# data          39
# usuario       39
# apelido       39
# texto         39
# retweet       39
# seguidores    39
# idioma        39
# lugar         39
# pais          39
# sigla         39
# latitude      39
# longitude     39
# hashtags      39
# dtype: int64

# %%
prop2=(M/len(banco))*100
prop2[1]
# Out:
# 0.4549165986235857

# %%
ministro1=banco[banco['texto'].str.contains('ministro')].count() #contando quantas vezes a palavra 'presidente' é cidada.
ministro2=banco[banco['texto'].str.contains('Ministro')].count()
M=ministro1+ministro2
M
# Out:
# data          39
# usuario       39
# apelido       39
# texto         39
# retweet       39
# seguidores    39
# idioma        39
# lugar         39
# pais          39
# sigla         39
# latitude      39
# longitude     39
# hashtags      39
# dtype: int64

# %%
d = np.array([prop1[1],prop2[1]])
d
# Out:
# array([1.69135658, 0.4549166 ])

# %%
pip install folium
# Out:
# Requirement already satisfied: folium in c:\programdata\anaconda3\lib\site-packages (0.11.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from folium) (1.18.5)
# Requirement already satisfied: branca>=0.3.0 in c:\programdata\anaconda3\lib\site-packages (from folium) (0.4.1)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from folium) (2.24.0)
# Requirement already satisfied: jinja2>=2.9 in c:\programdata\anaconda3\lib\site-packages (from folium) (2.11.2)
# Requirement already satisfied: idna<3,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (1.25.9)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\programdata\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (1.1.1)

# %%
mapa=folium.Map(location=[-15.776910,-47.87780],
  tiles='Stamen Terrain', zoom_start=10)
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium.Marker([-15.776910,-47.87780],tooltip='Clique aqui!', icon=folium.Icon(color='green')).add_to(mapa)#marcador comum

# %%
folium.CircleMarker(location=[-15.776910,-47.87780],
                   radius=10,
                   color='#3186cc',
                   fill=True,
                   fill_color='#3186cc').add_to(mapa)

# %%
coor=[]
for lat,lng in zip (BD.longitude.values[:1000],banco.latitude.values[:1000]):coor.append([lat,lng])

# %%
mapa=folium.Map(location=[-15.788497,-47.879873],zoom_start=10,titles='Stamen Torner')

# %%
mapa.add_child(plugins.HeatMap(coor))
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
len(coor)
# Out:
# 518

# %%
palavras = ['teste', 'assistente', 'estou', 'aqui', 'onde', 'ouro', 'adeus']
def f(p):
    return p.startswith('a') or p.startswith('e')

    print filter(f, palavras)
# Out:
#   File "<ipython-input-57-dd68891afe07>", line 5
#     print filter(f, palavras)
#           ^
# SyntaxError: invalid syntax

# %%
open('newfile','w').writelines([ line for line in open('textfile') if 'Apple' in line])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-63-b0d5c3940496> in <module>
# ----> 1 open(BD['texto']).writelines([ line for line in BD['texto']if 'oportunidades' in line])
#       2
#
# TypeError: expected str, bytes or os.PathLike object, not Series

# %%
def f(p):
    return p.startswith('a') or p.startswith('e')

    print filter(f, palavras)
# Out:
#   File "<ipython-input-61-866e0d0dc277>", line 4
#     print filter(f, palavras)
#           ^
# SyntaxError: invalid syntax

# %%
 print filter(f, palavras)
# Out:
#   File "<ipython-input-59-593e95622846>", line 1
#     print filter(f, palavras)
#           ^
# SyntaxError: invalid syntax
